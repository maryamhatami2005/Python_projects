# %%
import random
import string
def generate_pin_code(length: int = 4):
    return "".join([random.choice(string.digits) for n in range(length)])
    
pin = generate_pin_code(5)
pin
# Out:
# '57813'

# %%
list(random.choice(string.digits))
# Out:
# ['3']

# %%
"" .join([random.choice(string.digits) for n in range(4)])
# Out:
# '6780'

# %%
def generate_random_password(length: int = 8, include_nums: bool = True, include_symbols: bool = True):
    characters = string.ascii_letters
    if include_nums:
        characters += string.digits
    if include_symbols:
        characters += string.punctuation
    return "".join([random.choice(characters) for n in range(10)])

ranodom_pass = generate_random_password(8,True, False)
ranodom_pass
# Out:
# 'IRpDb0QYvh'

# %%
characters = string.ascii_letters
characters += string.punctuation
characters += string.digits
characters

"".join([random.choice(characters) for n in range(10)])
# Out:
# '#f{6!}nY84'

# %%
import nltk
def generate_memorable_password(length = 4,seprator = "-",upper = True, vocabluary = None):

    if vocabluary is None:
        vocabluary = nltk.corpus.words.words()
    password_words =  [random.choice(vocabluary) for n in range(4)]
    
    if upper:
        password_words = [word.upper() if random.choice([True ,False]) else word.lower() for word in password_words]
    return seprator.join(password_words)

memorable = generate_memorable_password()
memorable
# Out:
# 'fistnote-ASTROLOGISTIC-uracil-GLYOXALINE'

# %%
import nltk
"-". join([random.choice(nltk.corpus.words.words()) for n in range(8)])
# Out:
# 'deferment-pestiferousness-unstainedly-jugular-inspiratrix-metestick-incogent-uvulae'

# %%
words = [random.choice(nltk.corpus.words.words()) for n in range(8)]
[word.upper() if random.choice([True ,False]) else word.lower() for word in words]
# Out:
# ['repolymerize',
#  'solidifier',
#  'lithocystotomy',
#  'PERISPHERICAL',
#  'nacarat',
#  'unpiteously',
#  'denominationalize',
#  'BACKTRICK']

# %%
from random import choice
def generate_memorable_password(length = 4,seprator = "-",upper = True, vocabluary = None):

    if vocabluary is None:
        vocabluary = nltk.corpus.words.words()
    password_words =  [choice(vocabluary) for n in range(length)]
    
    if upper:
        password_words = [word.upper() if choice([True ,False]) else word.lower() for word in vocabluary]
    return seprator.join(password_words)

memorable = generate_memorable_password()
memorable
# Out:
# 'A-a-aa-AAL-AALII-aam-aani-AARDVARK-aardwolf-aaron-aaronic-aaronical-aaronite-aaronitic-AARU-AB-aba-ababdeh-ABABUA-abac-abaca-ABACATE-ABACAY-ABACINATE-ABACINATION-abaciscus-ABACIST-aback-abactinal-abactinally-abaction-abactor-ABACULUS-abacus-abadite-abaff-abaft-abaisance-abaiser-ABAISSED-ABALIENATE-ABALIENATION-abalone-ABAMA-abampere-ABANDON-abandonable-ABANDONED-abandonedly-abandonee-abandoner-ABANDONMENT-abanic-ABANTES-abaptiston-ABARAMBO-ABARIS-ABARTHROSIS-abarticular-ABARTICULATION-ABAS-abase-ABASED-abasedly-abasedness-abasement-abaser-abasgi-ABASH-ABASHED-abashedly-abashedness-abashless-abashlessly-ABASHMENT-ABASIA-abasic-ABASK-abassin-ABASTARDIZE-ABATABLE-abate-ABATEMENT-ABATER-abatis-ABATISED-ABATON-abator-abattoir-ABATUA-ABATURE-abave-abaxial-ABAXILE-abaze-ABB-ABBA-ABBACOMES-abbacy-abbadide-ABBAS-abbasi-abbassi-abbasside-ABBATIAL-ABBATICAL-ABBESS-abbey-ABBEYSTEDE-ABBIE-ABBOT-abbotcy-ABBOTNULLIUS-ABBOTSHIP-ABBREVIATE-abbreviately-abbreviation-ABBREVIATOR-ABBREVIATORY-ABBREVIAT
# ...
