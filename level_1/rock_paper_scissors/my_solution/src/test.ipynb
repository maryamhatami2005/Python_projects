# %%
play = RockPaperScissors("Mary", 5)

# %%
play.game()
# Out:
# Computer choosed: rock
# User choosed: rock
#
# Computer choosed: rock
# User choosed: paper
#
# Computer choosed: rock
# User choosed: scissors
#
# Computer score: 1
# User score: 1
# It's a Tie

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
name = "mary"
name.title()
# Out:
# 'Mary'
