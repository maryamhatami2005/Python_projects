# %%
import requests

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
import os

# %%
os.environ['EMAIL']
# Out:
# 'mary'

# %%
os.environ['py_pass'] = 'password'

# %%
os.environ['py_pass']
# Out:
# 'password'

# %%
import requests

# %%
import requests


url = "https://www.googleapis.com/books/v1/volumes"

params = {'q': 'Python programming'}

response = requests.get(url, params=params)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 1000000,
#  'items': [{'kind': 'books#volume',
#    'id': 'aJQILlLxRmAC',
#    'etag': 'BheTyP4iwKU',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/aJQILlLxRmAC',
#    'volumeInfo': {'title': 'Python Programming',
#     'subtitle': 'An Introduction to Computer Science',
#     'authors': ['John M. Zelle'],
#     'publisher': 'Franklin, Beedle & Associates, Inc.',
#     'publishedDate': '2004',
#     'description': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0. It is difficult for many students to master basic concepts in computer science and programming. A large portion of the confusion can be blamed on the complexity of the tools and materials that are traditionally used to teach CS1 and CS2. This textbook was written with a single overarching goal: to present the core concepts of computer science as simply as possible without being simplistic.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781887902991'},
#      {'type': 'ISBN_10', 'identifier': '1887902996'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 533,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'averageRating': 4,
#     'ratingsCount': 18,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.3.3.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=aJQILlLxRmAC&printsec=frontcover&dq=Python+programming&hl=&cd=1&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=aJQILlLxRmAC&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=aJQILlLxRmAC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Python_Programming-sample-pdf.acsm?id=aJQILlLxRmAC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=aJQILlLxRmAC&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0.'}},
#   {'kind': 'books#volume',
#    'id': 'I24KzgEACAAJ',
#    'etag': 'Hq+HBJGfyj8',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/I24KzgEACAAJ',
#    'volumeInfo': {'title': 'Python Programming',
#     'subtitle': "The Ultimate Beginner's Guide to Python Language Fundamentals, a Crash Course with Step-by-Step Exercises, Tips, and Tricks to Learn Programming in a Short Time",
#     'authors': ['John Russel'],
#     'publisher': 'John Russel',
#     'publishedDate': '2020-11-08',
#     'description': "Unsure where to get started with coding? Worried that learning a coding language will be too hard? Or do you want to learn the easiest programming language? Learning how to start with a new coding language is not always as easy as it may seem, and some beginners are worried that working in this kind of language is going to be difficult and they give up before trying. Maybe you have heard horror stories from those who tried to coding in the past, and nothing worked. The truth is... Python does work, and it is as simple as it seems! Python Programming is going to take the time to teach you, whether you are a total beginner or have worked with some coding in the past, how to handle the Python language and how to make it work for your needs. We will look not only at what this language is but give you some practical examples that can help you to start coding in this language in no time. You will learn: Why Python is Considered One of the Best Languages to Learn as a Beginner Step-by-Step Instructions to Download & Install Python language on Windows, Mac, and Linux 5 Common Mistakes to Avoid when You Start Coding Basics of Python Programming that Will Allow You to Write your First Program in No Time How to Handle Strings, Operators, Conditional Statements The One Thing You Need to Debug your Codes in Python Practical Exercises to Quickly Get Practice Simple Strategies to Write Clean, Understandable and Flexible Code With the help of Python Programming, you will be able to learn more about how coding in this language works, and how even someone with no coding experience can make it work. Keep in mind that you can never compare a well-structured guide, with free online resources like Youtube videos and Blogs (mostly out-dated). Whether you're completely new to programming or you are looking for a new language to expand your skills, you will find this book an invaluable tool for starting and mastering programming in Python. Would You Like to Know More? Get this Book Now to Master Python Programming!",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1913922987'},
#      {'type': 'ISBN_13', 'identifier': '9781913922986'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 142,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=I24KzgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=I24KzgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=I24KzgEACAAJ&dq=Python+programming&hl=&cd=2&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=I24KzgEACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=I24KzgEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=I24KzgEACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Would You Like to Know More? Get this Book Now to Master Python Programming!'}},
#   {'kind': 'books#volume',
#    'id': 'tQwzEAAAQBAJ',
#    'etag': 'RzJz4euHS6k',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/tQwzEAAAQBAJ',
#    'volumeInfo': {'title': 'Learn Python',
#     'subtitle': 'A Crash Course On Python Programming and How To Start Coding With It. Learn The Basics Of Machine Learning and Data Analysis',
#     'authors': ['Damon Parker'],
#     'publisher': 'Damon Parker',
#     'publishedDate': '2021-06-12',
#     'description': "Python programming language has rendered itself as the language of choice for coding beginners and advanced software programmers alike. This book is written to help you master the basic concepts of Python coding and how you can utilize your coding skills to analyze a large volume of data and uncover valuable information that can otherwise be easily lost in the volume. It was designed primarily to emphasize the readability of the programming code, and its syntax enables programmers to convey ideas using fewer lines of code. Python programming language increases the speed of operation while allowing for higher efficiency in creating system integrations. Some of the highlights of the book include: - Key features and advantages of learning to code Python as well as the history of how Python programming was created - Step-by-step instructions on how to install Python on your operating systems (Windows, Mac, and Linux) - The concept of Python data types is presented in exquisite detail with various examples of each data type - How to create Python variables - Comprehensive lists of a variety of built-in functions and methods supported by Python - Basic concepts of writing efficient and effective Python codes, focusing on various programming elements - How to write if and else statements to retrieve desired information from your data - For and While loops are explained with explicit details in an easy-to-understand language - Basic concepts of big data analysis and machine learning algorithms - A brief overview of various renowned machine learning libraries All the concepts are explained with standard Python coding syntax supported with relevant examples and followed by exercises to help you test and verify your understanding of those concepts. Finally, as an added bonus you will learn some Python tips and tricks to take your machine learning programming game to the next level. Remember, knowledge is power, and with the great power you will gather from this book, you will be armed to make sound personal and professional technological choices. Your Python programming skillset will improve drastically, and you will be poised to develop your very own machine learning model! Don't you think it can be that easy? If you really want to have proof of all this, don't waste any more time! Grab your copy now!",
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 141,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=tQwzEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=tQwzEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=tQwzEAAAQBAJ&printsec=frontcover&dq=Python+programming&hl=&cd=3&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=tQwzEAAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=tQwzEAAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 4.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 4.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=tQwzEAAAQBAJ&rdid=book-tQwzEAAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 4990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 4990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Learn_Python-sample-pdf.acsm?id=tQwzEAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=tQwzEAAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book is written to help you master the basic concepts of Python coding and how you can utilize your coding skills to analyze a large volume of data and uncover valuable information that can otherwise be easily lost in the volume.'}},
#   {'kind': 'books#volume',
#    'id': '1RTjxwEACAAJ',
#    'etag': 'C+OtVCBgOus',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/1RTjxwEACAAJ',
#    'volumeInfo': {'title': 'Learn Python Programming',
#     'subtitle': 'A Practical Introduction Guide to Learn Python. Learn Coding Faster with Hands-On Project. Crash Course',
#     'authors': ['Jason Crash'],
#     'publishedDate': '2019-07-16',
#     'description': "If you want a quick and practical guide to learn python, then keep reading Python is a programming language that is well-known for its simplicity and powerful features that can be used to make web and software applications. Python is often considered to be one of the highly recommended programming languages for beginners due to its robustness and a high number of practical resources that can help beginners to get improved quickly. This book deals Python in a simple language that can enrich the reader's mind and deliver programming concepts in an easy way such that the basic ideas of programming will be mastered. All concepts are given examples with a detailed structure to help the reader master the language very easily. Details such as variables and operators are explained in layman terms in a way that computer science students will appreciate along with non-programming background students. Below, we describe the most exciting parts of the book in detail. The book starts with a description detail advantages of Python, along with a detailed history that will help you understand the mystery of Python popularity The next section deals with installation of Python in different operating systems, followed by the explanation of basic building blocks of any programming language-namely, variables, data types, and operators. The next section deals with the if/else statements and loops. We then start a detailed review of functions and object-oriented programming, along with exception handling and file methods in our journey to the exploration of the Python world. This book gives layman explanations and examples for the topics, along with output and comments to avoid confusion. The Python coding language is one of the best programming languages out there for both beginners and more experienced programmers to learn how to use. Would You Like To Know More? Scrool up and click the buy now button",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1080867708'},
#      {'type': 'ISBN_13', 'identifier': '9781080867707'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 154,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=1RTjxwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=1RTjxwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=1RTjxwEACAAJ&dq=Python+programming&hl=&cd=4&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=1RTjxwEACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Learn_Python_Programming.html?hl=&id=1RTjxwEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=1RTjxwEACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book deals Python in a simple language that can enrich the reader&#39;s mind and deliver programming concepts in an easy way such that the basic ideas of programming will be mastered.'}},
#   {'kind': 'books#volume',
#    'id': 'kX-TDwAAQBAJ',
#    'etag': 'eWuLyeP71GQ',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/kX-TDwAAQBAJ',
#    'volumeInfo': {'title': 'Python',
#     'subtitle': "Beginner's Guide to Programming Code with Python",
#     'authors': ['Charlie Masterson'],
#     'publisher': 'E.C. Publishing via PublishDrive',
#     'publishedDate': '2017-11-17',
#     'description': "Learn Python programming today and begin your path towards Python programming mastery! In this Definitive Python Guide, you’re about to discover... How to program code in Python through learning the core essentials that every Python programmer must know. Python is a very popular programming language, and there are a great many books on the market concerning it. We cut to the chase and tell you why you should get this one: Here is a Preview of What You'll Learn... Essentials of Python programming. Quickly pick up the language and start applying the concepts to any code that you write Major facets of Python programming - including concepts you can apply to *any* language Various mechanics of Python programming: control flow, variables, lists/dictionaries, and classes – and why learning these core principles are important to Python programming success Object-oriented programming, its influence to today’s popular computer languages, and why it matters ... And much, much more! Added Benefits of owning this book: Get a better understanding of the Python programming language Learn the basic essentials of Python in order to gain the confidence to tackle more complex topics Gain the critical steps in your path towards Python programming mastery By implementing the lessons in this book, not only would you learn one of today’s popular computer languages, but it will serve as your guide in accomplishing all your Python goals – whether as a fun hobby or as a starting point into a successful and long term programming career. Take action today and get this book now to reach your Python programming goals.",
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'PKEY:6610000079537'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 81,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.48.46.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=kX-TDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=kX-TDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=kX-TDwAAQBAJ&printsec=frontcover&dq=Python+programming&hl=&cd=5&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=kX-TDwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=kX-TDwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 2.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 2.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=kX-TDwAAQBAJ&rdid=book-kX-TDwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 2990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 2990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Python-sample-epub.acsm?id=kX-TDwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Python-sample-pdf.acsm?id=kX-TDwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=kX-TDwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Learn Python programming today and begin your path towards Python programming mastery! In this Definitive Python Guide, you’re about to discover.'}},
#   {'kind': 'books#volume',
#    'id': 'uES4AwAAQBAJ',
#    'etag': '/lyYOwzKc3w',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uES4AwAAQBAJ',
#    'volumeInfo': {'title': 'Python Programming Techniques',
#     'subtitle': 'The Art of Coding and Programming Explained',
#     'authors': ['Lance Gifford'],
#     'publisher': 'Speedy Publishing LLC',
#     'publishedDate': '2014-04-13',
#     'description': '"Python Programming Techniques" is a book that is ideal for persons that are interested in learning about the basics of Python programming before they move on to learn more advanced techniques offered by the program. The book is not for those who have no interest at all in python programming. It is specifically geared for those individuals that have a need to learn how it all works whether it is for their job or for scholastic purposes. Coding and programming can be tricky and this text explains how the pitfalls can be avoided when in the long run.',
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781632873330'},
#      {'type': 'ISBN_10', 'identifier': '1632873338'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 44,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.3.5.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=uES4AwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=uES4AwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=uES4AwAAQBAJ&pg=PT14&dq=Python+programming&hl=&cd=6&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=uES4AwAAQBAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming_Techniques.html?hl=&id=uES4AwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Python_Programming_Techniques-sample-epub.acsm?id=uES4AwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Python_Programming_Techniques-sample-pdf.acsm?id=uES4AwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=uES4AwAAQBAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'The Art of <b>Coding</b> and <b>Programming</b> Explained Lance Gifford. CHAPTER 2 <b>PYTHON</b> BASIC SYNTAX The golden rule of any ... <b>Python</b> BasicSyntax All <b>programming</b> languages have what is called syntax. Syntax is.'}},
#   {'kind': 'books#volume',
#    'id': 'uGCdzAEACAAJ',
#    'etag': 'gRxSY0QAVv0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uGCdzAEACAAJ',
#    'volumeInfo': {'title': 'Python Programming for Beginners',
#     'subtitle': 'A Guide to Python Computer Language, Computer Programming, and Learning Python Fast!',
#     'authors': ['Joe Benton'],
#     'publishedDate': '2019-12-18',
#     'description': "This book explains the basics of Python programming language, how it works, and what kind of programs you can create with it. Through reading this guide, you will gain an understanding of the rules of writing Python code, its parameters, and syntax. You will learn how to write Python code yourself, and at the completion of this book have the ability to solve mathematical problems with Python, as well as create a wide array of different programs. This book is aimed at the beginner, and will help you to gain an understanding of computer programming - particularly Python programming, within a very short period of time!Here Is What You'll Learn About...What Is PythonWhat Is Python Used ForDifferent Modes Of PythonPython Statements & SyntaxVariables, Data, Operators, & ExpressionsDifferent Functions & CommandsHow To Create Your Own ProgramMuch, Much More!",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1761030922'},
#      {'type': 'ISBN_13', 'identifier': '9781761030925'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 32,
#     'printType': 'BOOK',
#     'categories': ['Computers'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=uGCdzAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=uGCdzAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=uGCdzAEACAAJ&dq=Python+programming&hl=&cd=7&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=uGCdzAEACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming_for_Beginners.html?hl=&id=uGCdzAEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=uGCdzAEACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book explains the basics of Python programming language, how it works, and what kind of programs you can create with it.'}},
#   {'kind': 'books#volume',
#    'id': 'UZs8wQEACAAJ',
#    'etag': 'tIytUIHc++8',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/UZs8wQEACAAJ',
#    'volumeInfo': {'title': 'Python Programming',
#     'subtitle': 'Python Programming from Beginner to Intermediate in 7 Days',
#     'authors': ['Cal Baron'],
#     'publisher': 'Independently Published',
#     'publishedDate': '2019-01-16',
#     'description': "Quickstart guide for Python Programming Python is an incredibly versatile and powerful programming language, but only if you know how to use it! Need to learn Python fast? Python can be used to create just about any kind of programming project you can imagine. When you understand how to program in Python, you unlock a world of computing power and possibilities. Get the most out of Python simply by following the easy coding examples and projects fully explained inside this guide. It doesn't matter if you have never programmed anything before. This step-by-step guide gives you everything you need to know to do more with Python than you ever thought possible! Fully up to date for 2019 Python has been around for a long time, but has evolved over the years. Save yourself the headache and frustration of trying to use a guide that just isn't up to date anymore! Brand new and fully up to date, this guide shows you exactly what you need to do to start programming in Python today!Here is a preview of what you will learn in this guide: Introduction The Basics The first languages The 1980's to today What is Python? Benefits of learning Python Getting familiar with the language How Python Works Objects and classes Attributes and methods Inheritance Loops Conditional statements Exceptions Modules, packages, and libraries How To Get Started Setting up the environment Installing Python Getting ready to code Coding your very first program Walkthroughs Prime number program Sending texts Sending plain-text email Drawing with Turtle Creating games Tips For Success Code everyday Find other beginners Try explaining Python out loud Check out other languages Have a plan for when you get stuck Recommended Resources And so much more! If you aren't a tech-savvy person or have no programming experience, have no fear! With this guide in your hands that will not be a barrier for you any longer. Learn Python programming quickly and easily when you grab this guide now!",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1794217010'},
#      {'type': 'ISBN_13', 'identifier': '9781794217010'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 106,
#     'printType': 'BOOK',
#     'categories': ['Technology & Engineering'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=UZs8wQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=UZs8wQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=UZs8wQEACAAJ&dq=Python+programming&hl=&cd=8&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=UZs8wQEACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=UZs8wQEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=UZs8wQEACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'If you aren&#39;t a tech-savvy person or have no programming experience, have no fear! With this guide in your hands that will not be a barrier for you any longer. Learn Python programming quickly and easily when you grab this guide now!'}},
#   {'kind': 'books#volume',
#    'id': 'pThFMQAACAAJ',
#    'etag': 'gaItL5BbRnA',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/pThFMQAACAAJ',
#    'volumeInfo': {'title': 'Python Programming for Beginners',
#     'subtitle': 'Crash Course',
#     'authors': ['Martin Laredo'],
#     'publisher': 'Createspace Independent Publishing Platform',
#     'publishedDate': '2017-01-23',
#     'description': 'Python Programming For Beginners - Description Python, an interactive programming language that is easy to understand once it has been learned. However, there are so many different parts to Python that is can seem intimidating. Through the help of this book, I am going to show you how Python can be simplified. In this book you will learn -Python basics -Strategies -Code -And so much more!',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1542711355'},
#      {'type': 'ISBN_13', 'identifier': '9781542711357'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 52,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=pThFMQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=pThFMQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=pThFMQAACAAJ&dq=Python+programming&hl=&cd=9&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=pThFMQAACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming_for_Beginners.html?hl=&id=pThFMQAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=pThFMQAACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Through the help of this book, I am going to show you how Python can be simplified. In this book you will learn -Python basics -Strategies -Code -And so much more!'}},
#   {'kind': 'books#volume',
#    'id': 'TFbyAQAACAAJ',
#    'etag': '5F22FiAmJWc',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/TFbyAQAACAAJ',
#    'volumeInfo': {'title': 'Python',
#     'subtitle': "2 Books in 1: Beginner's Guide + Best Practices to Programming Code with Python",
#     'authors': ['Charlie Masterson'],
#     'publisher': 'Createspace Independent Publishing Platform',
#     'publishedDate': '2017-02-22',
#     'description': "Python Best Seller: 2 Books In 1! For a limited time only, get to own this Amazon top seller for just $24.00! Regularly priced at $30.76. Own this Best-Selling Python Computer Programming Bundle that contains: Book 1 - Python: Beginner's Guide to Programming Code with Python Book 2 - Python: Best Practices to Programming Code with Python Learn Python programming today and begin your path towards Python programming mastery! Save time and money by learning the basic essentials of Python AND how to write better and more efficient Python code! Book 1 - Python: Beginner's Guide to Programming Code with Python In this Definitive Python Beginner's Guide, you're about to discover... How to program code in Python through learning the core essentials that every Python programmer must know. Python is a very popular programming language, and there are a great many books on the market concerning it. We cut to the chase and tell you why you should get this one: Here is a Preview of What You'll Learn... Essentials of Python programming. Quickly pick up the language and start applying the concepts to any code that you write Major facets of Python programming - including concepts you can apply to *any* language Various mechanics of Python programming: control flow, variables, lists/dictionaries, and classes - and why learning these core principles are important to Python programming success Object-oriented programming, its influence to today's popular computer languages, and why it matters ... And much, much more! Other Benefits of owning this book: Get a better understanding of the Python programming language Learn the basic essentials of Python in order to gain the confidence to tackle more complex topics Gain the critical steps in your path towards Python programming mastery By implementing the lessons in this book, not only would you learn one of today's popular computer language, but it will serve as your guide in accomplishing all your Python goals - whether as a fun hobby or as a starting point into a successful and long term programming career. Book 2 - Python: Best Practices to Programming Code with Python Are you tired of your Python code turning out wrong? Are you forever finding it difficult to read your code, to spot where the problems are because it is, quite frankly, a mess? Are you fed up with reading so-called Best Practice guides that leave you more confused than you were when you started? This book -Python: Best Practices to Programming Code with Python-, will give you a straightforward guide on how to write better Python code. With this book, you will learn: General Concepts of Python Coding Python Coding Recommendations The best way to layout Python Code How to write comments Writing Conventions to follow How to write Function and Method Arguments ... And much, much more! Added Benefits of owning this book: Gain a better grasp of efficient and effective Python code to achieve programming success Speed up your programming abilities by avoiding time-wasting mistakes Gain the most important Best Practice concepts in your path towards Python programming mastery! By reading my Best Practice guide for Python coding, you will learn the best way to write better code, code that is readable and that others can understand. Take action today and own this book for a limited time discount. Scroll to the top of the page and select the -Buy now- button.",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1543292755'},
#      {'type': 'ISBN_13', 'identifier': '9781543292756'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 162,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=TFbyAQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=TFbyAQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=TFbyAQAACAAJ&dq=Python+programming&hl=&cd=10&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=TFbyAQAACAAJ&dq=Python+programming&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Python.html?hl=&id=TFbyAQAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=TFbyAQAACAAJ&hl=&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'This book &quot;Python: Best Practices to Programming Code with Python&quot;, will give you a straightforward guide on how to write better Python code.'}}]}

# %%
import os
import requests

# %%
params = {
    'api_key' : os.environ['GIPHY_API_KEY'],
}

# %%
url = "https://api.giphy.com/v1/gifs/trending"
response = requests.get(url, params=params)

# %%
response.json()
# Out:
# {'data': [{'type': 'gif',
#    'id': 'BSOgP93qIDUQ0',
#    'url': 'https://giphy.com/gifs/oscars-robert-duvall-academy-awards-nominee-BSOgP93qIDUQ0',
#    'slug': 'oscars-robert-duvall-academy-awards-nominee-BSOgP93qIDUQ0',
#    'bitly_gif_url': 'http://gph.is/1TDim7f',
#    'bitly_url': 'http://gph.is/1TDim7f',
#    'embed_url': 'https://giphy.com/embed/BSOgP93qIDUQ0',
#    'username': 'oscars',
#    'source': '',
#    'title': 'Robert Duvall Oscars GIF by The Academy Awards',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2016-02-23 16:42:02',
#    'trending_datetime': '2026-02-16 18:24:25',
#    'images': {'original': {'height': '270',
#      'width': '480',
#      'size': '2409545',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.gif',
#      'mp4_size': '289422',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.mp4',
#      'webp_size': '623460',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.webp',
#      'frames': '42',
#      'hash': '7ac4c9feed394162063e8d2fd0a582a1'},
#     'downsized': {'height': '270',
#      'width': '480',
#      'size': '1423778',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-downsized.gif'},
#     'downsized_large': {'height': '270',
#      'width': '480',
#      'size': '2409545',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.gif'},
#     'downsized_medium': {'height': '270',
#      'width': '480',
#      'size': '2409545',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.gif'},
#     'downsized_small': {'height': '222',
#      'width': '394',
#      'mp4_size': '119391',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '270',
#      'width': '480',
#      'size': '34830',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-downsized_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '356',
#      'size': '1042515',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200.gif',
#      'mp4_size': '204782',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200.mp4',
#      'webp_size': '417698',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '356',
#      'size': '160452',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200_d.gif',
#      'webp_size': '93096',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '178',
#      'size': '375846',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100.gif',
#      'mp4_size': '77358',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100.mp4',
#      'webp_size': '167384',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '178',
#      'size': '10784',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '356',
#      'size': '25308',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200_s.gif'},
#     'fixed_width': {'height': '113',
#      'width': '200',
#      'size': '471168',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w.gif',
#      'mp4_size': '86657',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w.mp4',
#      'webp_size': '192258',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w.webp'},
#     'fixed_width_downsampled': {'height': '113',
#      'width': '200',
#      'size': '68424',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w_d.gif',
#      'webp_size': '36534',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w_d.webp'},
#     'fixed_width_small': {'height': '57',
#      'width': '100',
#      'size': '143128',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100w.gif',
#      'mp4_size': '33948',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100w.mp4',
#      'webp_size': '76702',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100w.webp'},
#     'fixed_width_small_still': {'height': '57',
#      'width': '100',
#      'size': '4155',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/100w_s.gif'},
#     'fixed_width_still': {'height': '113',
#      'width': '200',
#      'size': '13884',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/200w_s.gif'},
#     'looping': {'height': '270',
#      'width': '480',
#      'mp4_size': '1547971',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-loop.mp4'},
#     'original_still': {'height': '270',
#      'width': '480',
#      'size': '84674',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy_s.gif'},
#     'original_mp4': {'height': '270',
#      'width': '480',
#      'mp4_size': '289422',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy.mp4'},
#     'preview': {'height': '184',
#      'width': '327',
#      'mp4_size': '37992',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-preview.mp4'},
#     'preview_gif': {'height': '50',
#      'width': '89',
#      'size': '48674',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-preview.gif'},
#     'preview_webp': {'height': '118',
#      'width': '210',
#      'size': '49594',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/giphy-preview.webp'},
#     '480w_still': {'height': '270',
#      'width': '480',
#      'size': '2409545',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/BSOgP93qIDUQ0/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/oscars/aLAlu5piMzjQ.jpg',
#     'banner_image': 'https://media3.giphy.com/headers/oscars/enlbBiKZqHl2.jpg',
#     'banner_url': 'https://media3.giphy.com/headers/oscars/enlbBiKZqHl2.jpg',
#     'profile_url': 'https://giphy.com/oscars/',
#     'username': 'oscars',
#     'display_name': 'The Academy Awards',
#     'description': 'Welcome to the official Oscars Giphy page.',
#     'instagram_url': 'https://instagram.com/TheAcademy',
#     'website_url': 'http://oscar.go.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9QlNPZ1A5M3FJRFVRMCZjdD1n',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9QlNPZ1A5M3FJRFVRMCZjdD1n&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9QlNPZ1A5M3FJRFVRMCZjdD1n&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9QlNPZ1A5M3FJRFVRMCZjdD1n&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': 'qWEmu91jMvp96',
#    'url': 'https://giphy.com/gifs/to-kill-a-mockingbird-robert-duvall-mary-badham-qWEmu91jMvp96',
#    'slug': 'to-kill-a-mockingbird-robert-duvall-mary-badham-qWEmu91jMvp96',
#    'bitly_gif_url': 'http://gph.is/1kFZUM3',
#    'bitly_url': 'http://gph.is/1kFZUM3',
#    'embed_url': 'https://giphy.com/embed/qWEmu91jMvp96',
#    'username': 'boomunderground',
#    'source': '',
#    'title': ' ',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2016-01-04 18:40:59',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '270',
#      'width': '480',
#      'size': '4671651',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy.gif',
#      'mp4_size': '315722',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy.mp4',
#      'webp_size': '1080822',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy.webp',
#      'frames': '105',
#      'hash': '6323d6e51c01bbae6739a4ee4b2a1bf1'},
#     'downsized': {'height': '270',
#      'width': '480',
#      'size': '1960393',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-downsized.gif'},
#     'downsized_large': {'height': '270',
#      'width': '480',
#      'size': '4671651',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy.gif'},
#     'downsized_medium': {'height': '270',
#      'width': '480',
#      'size': '3674518',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-downsized-medium.gif'},
#     'downsized_small': {'height': '226',
#      'width': '401',
#      'mp4_size': '180887',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '270',
#      'width': '480',
#      'size': '43123',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-downsized_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '356',
#      'size': '2260708',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200.gif',
#      'mp4_size': '203949',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200.mp4',
#      'webp_size': '807930',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '356',
#      'size': '170381',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200_d.gif',
#      'webp_size': '103050',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '178',
#      'size': '791915',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100.gif',
#      'mp4_size': '72412',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100.mp4',
#      'webp_size': '330062',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '178',
#      'size': '11795',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '356',
#      'size': '30556',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200_s.gif'},
#     'fixed_width': {'height': '113',
#      'width': '200',
#      'size': '797827',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w.gif',
#      'mp4_size': '85329',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w.mp4',
#      'webp_size': '335600',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w.webp'},
#     'fixed_width_downsampled': {'height': '113',
#      'width': '200',
#      'size': '60883',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w_d.gif',
#      'webp_size': '38026',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w_d.webp'},
#     'fixed_width_small': {'height': '57',
#      'width': '100',
#      'size': '314506',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100w.gif',
#      'mp4_size': '26211',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100w.mp4',
#      'webp_size': '118906',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100w.webp'},
#     'fixed_width_small_still': {'height': '57',
#      'width': '100',
#      'size': '4120',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/100w_s.gif'},
#     'fixed_width_still': {'height': '113',
#      'width': '200',
#      'size': '14540',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/200w_s.gif'},
#     'looping': {'height': '270',
#      'width': '480',
#      'mp4_size': '687818',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-loop.mp4'},
#     'original_still': {'height': '270',
#      'width': '480',
#      'size': '108174',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy_s.gif'},
#     'original_mp4': {'height': '270',
#      'width': '480',
#      'mp4_size': '315722',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy.mp4'},
#     'preview': {'height': '270',
#      'width': '480',
#      'mp4_size': '38535',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-preview.mp4'},
#     'preview_gif': {'height': '52',
#      'width': '92',
#      'size': '48903',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-preview.gif'},
#     'preview_webp': {'height': '162',
#      'width': '288',
#      'size': '49160',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/giphy-preview.webp'},
#     '480w_still': {'height': '270',
#      'width': '480',
#      'size': '4671651',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/qWEmu91jMvp96/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/default2.gif',
#     'banner_image': '',
#     'banner_url': '',
#     'profile_url': 'https://giphy.com/channel/boomunderground/',
#     'username': 'boomunderground',
#     'display_name': 'BoomUnderground',
#     'description': '',
#     'instagram_url': '',
#     'website_url': '',
#     'is_verified': False},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9cVdFbXU5MWpNdnA5NiZjdD1n',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9cVdFbXU5MWpNdnA5NiZjdD1n&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9cVdFbXU5MWpNdnA5NiZjdD1n&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9cVdFbXU5MWpNdnA5NiZjdD1n&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': '26gsk7q9IsTIYBT1e',
#    'url': 'https://giphy.com/gifs/oscars-academy-awards-oscars-1984-26gsk7q9IsTIYBT1e',
#    'slug': 'oscars-academy-awards-oscars-1984-26gsk7q9IsTIYBT1e',
#    'bitly_gif_url': 'http://gph.is/2jTyGVe',
#    'bitly_url': 'http://gph.is/2jTyGVe',
#    'embed_url': 'https://giphy.com/embed/26gsk7q9IsTIYBT1e',
#    'username': 'oscars',
#    'source': '',
#    'title': 'Robert Duvall Oscars GIF by The Academy Awards',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2017-02-01 02:46:42',
#    'trending_datetime': '2026-02-16 18:24:14',
#    'images': {'original': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.gif',
#      'mp4_size': '496708',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.mp4',
#      'webp_size': '657266',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.webp',
#      'frames': '31',
#      'hash': '9d4feee33eee3d09af4e2b168349e3f6'},
#     'downsized': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.gif'},
#     'downsized_large': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.gif'},
#     'downsized_medium': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.gif'},
#     'downsized_small': {'height': '192',
#      'width': '256',
#      'mp4_size': '50979',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '267',
#      'size': '549742',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200.gif',
#      'mp4_size': '110687',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200.mp4',
#      'webp_size': '275506',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '267',
#      'size': '115501',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200_d.gif',
#      'webp_size': '82236',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '134',
#      'size': '181599',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100.gif',
#      'mp4_size': '40064',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100.mp4',
#      'webp_size': '107878',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '134',
#      'size': '6496',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '267',
#      'size': '17394',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200_s.gif'},
#     'fixed_width': {'height': '150',
#      'width': '200',
#      'size': '394717',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w.gif',
#      'mp4_size': '71975',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w.mp4',
#      'webp_size': '188630',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w.webp'},
#     'fixed_width_downsampled': {'height': '150',
#      'width': '200',
#      'size': '93780',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w_d.gif',
#      'webp_size': '52440',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w_d.webp'},
#     'fixed_width_small': {'height': '75',
#      'width': '100',
#      'size': '116044',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100w.gif',
#      'mp4_size': '25231',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100w.mp4',
#      'webp_size': '71542',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100w.webp'},
#     'fixed_width_small_still': {'height': '75',
#      'width': '100',
#      'size': '4449',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/100w_s.gif'},
#     'fixed_width_still': {'height': '150',
#      'width': '200',
#      'size': '15315',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/200w_s.gif'},
#     'looping': {'height': '360',
#      'width': '480',
#      'mp4_size': '2572478',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy-loop.mp4'},
#     'original_still': {'height': '360',
#      'width': '480',
#      'size': '95688',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy_s.gif'},
#     'original_mp4': {'height': '360',
#      'width': '480',
#      'mp4_size': '496708',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy.mp4'},
#     'preview': {'height': '216',
#      'width': '288',
#      'mp4_size': '35769',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy-preview.mp4'},
#     'preview_gif': {'height': '62',
#      'width': '83',
#      'size': '49332',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy-preview.gif'},
#     'preview_webp': {'height': '126',
#      'width': '168',
#      'size': '47276',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/giphy-preview.webp'},
#     '480w_still': {'height': '360',
#      'width': '480',
#      'size': '1960215',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/26gsk7q9IsTIYBT1e/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/oscars/aLAlu5piMzjQ.jpg',
#     'banner_image': 'https://media3.giphy.com/headers/oscars/enlbBiKZqHl2.jpg',
#     'banner_url': 'https://media3.giphy.com/headers/oscars/enlbBiKZqHl2.jpg',
#     'profile_url': 'https://giphy.com/oscars/',
#     'username': 'oscars',
#     'display_name': 'The Academy Awards',
#     'description': 'Welcome to the official Oscars Giphy page.',
#     'instagram_url': 'https://instagram.com/TheAcademy',
#     'website_url': 'http://oscar.go.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9MjZnc2s3cTlJc1RJWUJUMWUmY3Q9Zw',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9MjZnc2s3cTlJc1RJWUJUMWUmY3Q9Zw&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9MjZnc2s3cTlJc1RJWUJUMWUmY3Q9Zw&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9MjZnc2s3cTlJc1RJWUJUMWUmY3Q9Zw&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': 'fUQ4rhUZJYiQsas6WD',
#    'url': 'https://giphy.com/gifs/muppetwiki-sesame-street-muppets-elmo-fUQ4rhUZJYiQsas6WD',
#    'slug': 'muppetwiki-sesame-street-muppets-elmo-fUQ4rhUZJYiQsas6WD',
#    'bitly_gif_url': 'https://gph.is/g/Z5jLdoQ',
#    'bitly_url': 'https://gph.is/g/Z5jLdoQ',
#    'embed_url': 'https://giphy.com/embed/fUQ4rhUZJYiQsas6WD',
#    'username': 'muppetwiki',
#    'source': '',
#    'title': 'Happy Sesame Street GIF by Muppet Wiki',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2023-10-15 15:35:34',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '300',
#      'width': '400',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.gif',
#      'mp4_size': '357111',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.mp4',
#      'webp_size': '876194',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.webp',
#      'frames': '33',
#      'hash': '45577accf4e33e486627a9d75c0c4e14'},
#     'downsized': {'height': '300',
#      'width': '400',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.gif'},
#     'downsized_large': {'height': '300',
#      'width': '400',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.gif'},
#     'downsized_medium': {'height': '300',
#      'width': '400',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.gif'},
#     'downsized_small': {'height': '184',
#      'width': '245',
#      'mp4_size': '179427',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '300',
#      'width': '400',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '266',
#      'size': '685440',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200.gif',
#      'mp4_size': '131332',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200.mp4',
#      'webp_size': '345382',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '266',
#      'size': '128916',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200_d.gif',
#      'webp_size': '79862',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '134',
#      'size': '207405',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100.gif',
#      'mp4_size': '38580',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100.mp4',
#      'webp_size': '96128',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '134',
#      'size': '10804',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '266',
#      'size': '39661',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200_s.gif'},
#     'fixed_width': {'height': '150',
#      'width': '200',
#      'size': '411160',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w.gif',
#      'mp4_size': '78275',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w.mp4',
#      'webp_size': '178976',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w.webp'},
#     'fixed_width_downsampled': {'height': '150',
#      'width': '200',
#      'size': '78902',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w_d.gif',
#      'webp_size': '49284',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w_d.webp'},
#     'fixed_width_small': {'height': '76',
#      'width': '100',
#      'size': '127816',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100w.gif',
#      'mp4_size': '26567',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100w.mp4',
#      'webp_size': '61306',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100w.webp'},
#     'fixed_width_small_still': {'height': '76',
#      'width': '100',
#      'size': '7832',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/100w_s.gif'},
#     'fixed_width_still': {'height': '150',
#      'width': '200',
#      'size': '22389',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/200w_s.gif'},
#     'looping': {'height': '360',
#      'width': '480',
#      'mp4_size': '5879628',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy-loop.mp4'},
#     'original_still': {'height': '300',
#      'width': '400',
#      'size': '43647',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy_s.gif'},
#     'original_mp4': {'height': '300',
#      'width': '400',
#      'mp4_size': '357111',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy.mp4'},
#     'preview': {'height': '112',
#      'width': '149',
#      'mp4_size': '41391',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy-preview.mp4'},
#     'preview_gif': {'height': '76',
#      'width': '100',
#      'size': '40637',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy-preview.gif'},
#     'preview_webp': {'height': '76',
#      'width': '100',
#      'size': '44590',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/giphy-preview.webp'},
#     '480w_still': {'height': '360',
#      'width': '480',
#      'size': '1019672',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fUQ4rhUZJYiQsas6WD/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/muppetwiki/bFJ8U3JYv8lm.jpg',
#     'banner_image': '',
#     'banner_url': '',
#     'profile_url': 'https://giphy.com/muppetwiki/',
#     'username': 'muppetwiki',
#     'display_name': 'Muppet Wiki',
#     'description': 'Muppet Wiki is the encyclopedic result of fans and professionals working together to build the best resource about the Muppets, Sesame Street, and Jim Henson',
#     'instagram_url': 'https://instagram.com/muppetwiki',
#     'website_url': 'http://www.muppetwiki.com',
#     'is_verified': False},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9ZlVRNHJoVVpKWWlRc2FzNldEJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9ZlVRNHJoVVpKWWlRc2FzNldEJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9ZlVRNHJoVVpKWWlRc2FzNldEJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9ZlVRNHJoVVpKWWlRc2FzNldEJmN0PWc&action_type=SENT'}},
#    'alt_text': 'Sesame Street gif. Elmo dances gleefully with his head back, mouth gaping open, and arms in the air as his legs flutter.',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': 'tXL4FHPSnVJ0A',
#    'url': 'https://giphy.com/gifs/kim-novak-tXL4FHPSnVJ0A',
#    'slug': 'kim-novak-tXL4FHPSnVJ0A',
#    'bitly_gif_url': 'http://gph.is/2cCs4a6',
#    'bitly_url': 'http://gph.is/2cCs4a6',
#    'embed_url': 'https://giphy.com/embed/tXL4FHPSnVJ0A',
#    'username': '',
#    'source': '',
#    'title': 'Bored Cabin Fever GIF',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2016-09-25 07:11:14',
#    'trending_datetime': '2021-05-17 05:00:12',
#    'images': {'original': {'height': '316',
#      'width': '480',
#      'size': '701854',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.gif',
#      'mp4_size': '183747',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.mp4',
#      'webp_size': '275926',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.webp',
#      'frames': '21',
#      'hash': '0b1d55300548f571d8bae6a020ae0e44'},
#     'downsized': {'height': '316',
#      'width': '480',
#      'size': '701854',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.gif'},
#     'downsized_large': {'height': '316',
#      'width': '480',
#      'size': '701854',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.gif'},
#     'downsized_medium': {'height': '316',
#      'width': '480',
#      'size': '701854',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy.gif'},
#     'downsized_small': {'height': '316',
#      'width': '478',
#      'mp4_size': '183747',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '316',
#      'width': '480',
#      'size': '701854',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '298',
#      'size': '276130',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/200.gif',
#      'mp4_size': '77422',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/200.mp4',
#      'webp_size': '145360',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '298',
#      'size': '83821',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/200_d.gif',
#      'webp_size': '57478',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '150',
#      'size': '89559',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/tXL4FHPSnVJ0A/100.gif',
#      'mp4_size': '21875',
# ...
#      'webp_size': '213198',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/200w.webp'},
#     'fixed_width_downsampled': {'height': '112',
#      'width': '200',
#      'size': '73848',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/200w_d.gif',
#      'webp_size': '40788',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/200w_d.webp'},
#     'fixed_width_small': {'height': '56',
#      'width': '100',
#      'size': '109069',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/100w.gif',
#      'mp4_size': '12682',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/100w.mp4',
#      'webp_size': '76572',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/100w.webp'},
#     'fixed_width_small_still': {'height': '56',
#      'width': '100',
#      'size': '4262',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/100w_s.gif'},
#     'fixed_width_still': {'height': '112',
#      'width': '200',
#      'size': '15556',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/200w_s.gif'},
#     'looping': {'height': '268',
#      'width': '480',
#      'mp4_size': '1980689',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy-loop.mp4'},
#     'original_still': {'height': '137',
#      'width': '245',
#      'size': '28186',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy_s.gif'},
#     'original_mp4': {'height': '268',
#      'width': '480',
#      'mp4_size': '482278',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy.mp4'},
#     'preview': {'height': '136',
#      'width': '244',
#      'mp4_size': '38590',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy-preview.mp4'},
#     'preview_gif': {'height': '58',
#      'width': '104',
#      'size': '49534',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy-preview.gif'},
#     'preview_webp': {'height': '88',
#      'width': '158',
#      'size': '40166',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/giphy-preview.webp'},
#     '480w_still': {'height': '268',
#      'width': '480',
#      'size': '563587',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7SYc4ycHGUv4c/480w_s.jpg'}},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9N1NZYzR5Y0hHVXY0YyZjdD1n',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9N1NZYzR5Y0hHVXY0YyZjdD1n&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9N1NZYzR5Y0hHVXY0YyZjdD1n&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9N1NZYzR5Y0hHVXY0YyZjdD1n&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': '3og0IuE1EjI5ZQzr3i',
#    'url': 'https://giphy.com/gifs/cbc-funny-comedy-3og0IuE1EjI5ZQzr3i',
#    'slug': 'cbc-funny-comedy-3og0IuE1EjI5ZQzr3i',
#    'bitly_gif_url': 'http://gph.is/2oeUSJH',
#    'bitly_url': 'http://gph.is/2oeUSJH',
#    'embed_url': 'https://giphy.com/embed/3og0IuE1EjI5ZQzr3i',
#    'username': 'cbc',
#    'source': '',
#    'title': 'Excited Schitts Creek GIF by CBC',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2017-03-29 05:29:50',
#    'trending_datetime': '2021-03-04 13:45:11',
#    'images': {'original': {'height': '501',
#      'width': '500',
#      'size': '3227111',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.gif',
#      'mp4_size': '382207',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.mp4',
#      'webp_size': '1409194',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.webp',
#      'frames': '38',
#      'hash': '2860474727cb98452854812671184ed3'},
#     'downsized': {'height': '400',
#      'width': '400',
#      'size': '1879005',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-downsized.gif'},
#     'downsized_large': {'height': '501',
#      'width': '500',
#      'size': '3227111',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.gif'},
#     'downsized_medium': {'height': '501',
#      'width': '500',
#      'size': '3227111',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.gif'},
#     'downsized_small': {'height': '288',
#      'width': '288',
#      'mp4_size': '177419',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '400',
#      'width': '400',
#      'size': '59471',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-downsized_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '200',
#      'size': '593394',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200.gif',
#      'mp4_size': '72644',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200.mp4',
#      'webp_size': '256226',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '200',
#      'size': '91645',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200_d.gif',
#      'webp_size': '58632',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '100',
#      'size': '185836',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100.gif',
#      'mp4_size': '26465',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100.mp4',
#      'webp_size': '79702',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '100',
#      'size': '5726',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '200',
#      'size': '15680',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200_s.gif'},
#     'fixed_width': {'height': '200',
#      'width': '200',
#      'size': '593394',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w.gif',
#      'mp4_size': '72644',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w.mp4',
#      'webp_size': '206136',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w.webp'},
#     'fixed_width_downsampled': {'height': '200',
#      'width': '200',
#      'size': '91645',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w_d.gif',
#      'webp_size': '58632',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w_d.webp'},
#     'fixed_width_small': {'height': '100',
#      'width': '100',
#      'size': '185836',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100w.gif',
#      'mp4_size': '26465',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100w.mp4',
#      'webp_size': '79702',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100w.webp'},
#     'fixed_width_small_still': {'height': '100',
#      'width': '100',
#      'size': '5726',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/100w_s.gif'},
#     'fixed_width_still': {'height': '200',
#      'width': '200',
#      'size': '15680',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/200w_s.gif'},
#     'looping': {'height': '480',
#      'width': '480',
#      'mp4_size': '5464170',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-loop.mp4'},
#     'original_still': {'height': '501',
#      'width': '500',
#      'size': '63698',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy_s.gif'},
#     'original_mp4': {'height': '480',
#      'width': '480',
#      'mp4_size': '382207',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy.mp4'},
#     'preview': {'height': '150',
#      'width': '150',
#      'mp4_size': '42024',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-preview.mp4'},
#     'preview_gif': {'height': '80',
#      'width': '80',
#      'size': '36556',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-preview.gif'},
#     'preview_webp': {'height': '100',
#      'width': '100',
#      'size': '16970',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/giphy-preview.webp'},
#     '480w_still': {'height': '481',
#      'width': '480',
#      'size': '3227111',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3og0IuE1EjI5ZQzr3i/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/cbc/kZeSLaAAgBVr.gif',
#     'banner_image': '',
#     'banner_url': '',
#     'profile_url': 'https://giphy.com/cbc/',
#     'username': 'cbc',
#     'display_name': 'CBC',
#     'description': 'Canadian Broadcasting Corporation \r\n#loveCBC',
#     'instagram_url': 'https://instagram.com/cbc',
#     'website_url': 'http://cbc.ca/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9M29nMEl1RTFFakk1WlF6cjNpJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9M29nMEl1RTFFakk1WlF6cjNpJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9M29nMEl1RTFFakk1WlF6cjNpJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4cnpjbG0wbGs0ejBxYW1ldXZ4cWtrODNpZHRibGNrb2t2ejN5bTYwMyZnaWZfaWQ9M29nMEl1RTFFakk1WlF6cjNpJmN0PWc&action_type=SENT'}},
#    'alt_text': "Schitt's Creek gif. Catherine O'Hara as Moira sits up pleased and claps her hands excitedly.",
#    'is_low_contrast': False}],
#  'meta': {'status': 200,
#   'msg': 'OK',
#   'response_id': 'rzclm0lk4z0qameuvxqkk83idtblckokvz3ym603'},
#  'pagination': {'total_count': 191, 'count': 50, 'offset': 0}}

# %%
for gif in response.json()['data']:
    print(gif['url'])
# Out:
# https://giphy.com/gifs/oscars-robert-duvall-academy-awards-nominee-BSOgP93qIDUQ0
# https://giphy.com/gifs/to-kill-a-mockingbird-robert-duvall-mary-badham-qWEmu91jMvp96
# https://giphy.com/gifs/oscars-academy-awards-oscars-1984-26gsk7q9IsTIYBT1e
# https://giphy.com/gifs/muppetwiki-sesame-street-muppets-elmo-fUQ4rhUZJYiQsas6WD
# https://giphy.com/gifs/kim-novak-tXL4FHPSnVJ0A
# https://giphy.com/gifs/TheSwoon-lTRlLRfnWiDrALY27Z
# https://giphy.com/gifs/laughing-ryan-gosling-GpyS1lJXJYupG
# https://giphy.com/gifs/hug-ghost-2GDHOfqcmYIX6
# https://giphy.com/gifs/no-ji6zzUZwNIuLS
# https://giphy.com/gifs/yosub-money-donald-duck-cash-xTiTnqUxyWbsAXq7Ju
# https://giphy.com/gifs/happy-birthday-robert-duvall-born-today-lXHj6CJpdEhxe
# https://giphy.com/gifs/paramountmovies-tom-cruise-days-of-thunder-Q94xG7iBePgBgzsHur
# https://giphy.com/gifs/nbcolympics-milano-cortina-2026-olympics-2WgW7efQnKaXEnkykL
# https://giphy.com/gifs/movie-godfather-the-3o7buiEoTOxsTijAGs
# https://giphy.com/gifs/baby-yay-HHzBaXsra2MHciRNQr
# https://giphy.com/gifs/bombaysoftwares-waiting-mr-bean-still-um2kBnfo55iW4ZH1Fa
# https://giphy.com/gifs/ExplainingWhy-japan-cherry-blossoms-hanami-5TYX6H897ob6cJNpze
# https://giphy.com/gifs/lol-laugh-laughing-gj0QdZ9FgqGhOBNlFS
# https://giphy.com/gifs/milk-and-mocha-bear-IzXiddo2twMmdmU8Lv
# https://giphy.com/gifs/oceanx-help-halp-so-confused-7SIdExk63rTPXhbbbt
# https://giphy.com/gifs/rich-poodle-maltipoo-cXMFmN3edhlHI5vRsG
# https://giphy.com/gifs/hboindia-days-of-thunder-l4FGJEP27S4seSMzm
# https://giphy.com/gifs/network-faye-dunaway-diana-christensen-PIBn1YQRmfpDv1VY6a
# https://giphy.com/gifs/djemilah-yes-im-excited-becoming-the-big-me-joSNxeswxuc74Juo8X
# https://giphy.com/gifs/sad-cry-sadness-H6cmWzp6LGFvqjidB7
# https://giphy.com/gifs/Capcom-street-fighter-capcom-mai-shiranui-XNeVE1IYq9RWM57Rf2
# https://giphy.com/gifs/dtGIRL0FDp6nnOPGb5
# https://giphy.com/gifs/love-disney-girl-EvYHHSntaIl5m
# https://giphy.com/gifs/robert-downey-jr-sigh-confused-116a8zosxwA0SI
# https://giphy.com/gifs/money-make-it-rain-MFsqcBSoOKPbjtmvWz
# https://giphy.com/gifs/Cinisioracing-days-thunder-of-FuAHFCWSl7Zyl70kca
# https://giphy.com/gifs/colbertlateshow-stephen-colbert-the-late-show-robert-duvall-FYujlpWS3Oj3x1oqk2
# https://giphy.com/gifs/american-horror-story-ahs-excited-OfkGZ5H2H3f8Y
# https://giphy.com/gifs/time-mr-bean-look-at-the-QBd2kLB5qDmysEXre9
# https://giphy.com/gifs/couple-keidilexer-travel-buddy-MBWFeFZkL2xs1qz1Va
# https://giphy.com/gifs/lol-laughing-hehe-Tq2tPTrQANKfK
# https://giphy.com/gifs/PudgyMemez-pudgypenguins-pengu-penguins-uakdGGShmMS0KYfTgp
# https://giphy.com/gifs/reaction-SAAMcPRfQpgyI
# https://giphy.com/gifs/money-px8O7NANzzaqk
# https://giphy.com/gifs/nascar-racing-2021-daytona-o4gzxBLLMDzmWY4nSY
# https://giphy.com/gifs/network-faye-dunaway-diana-christensen-VFEIUJdaILd5i0ueS6
# https://giphy.com/gifs/axu6dFuca4HKM
# https://giphy.com/gifs/waiting-hd-well-were-9SIXFu7bIUYHhFc19G
# https://giphy.com/gifs/Capcom-street-fighter-capcom-fighting-game-L6xwAV5uXwBpedymo2
# https://giphy.com/gifs/Goosify-funny-laughing-haha-vbqr9NgKRuKq7meXsi
# https://giphy.com/gifs/hug-couple-hugging-KG5oq4vesf9r8JbBEN
# https://giphy.com/gifs/what-the-fuck-wtf-ukGm72ZLZvYfS
# https://giphy.com/gifs/12QCczVAjPAfvi
# https://giphy.com/gifs/the-godfather-francis-ford-coppola-james-caan-7SYc4ycHGUv4c
# https://giphy.com/gifs/cbc-funny-comedy-3og0IuE1EjI5ZQzr3i
