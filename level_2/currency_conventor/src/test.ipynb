# %%
import os
import requests

# %%
params = {
    'api_key' : os.environ['GIPHY_API_KEY'],
}

# %%
import requests

url = "https://api.giphy.com/v1/gifs/trending"
response = requests.get(url, params=params)

# %%
response.json()
# Out:
# {'data': [{'type': 'gif',
#    'id': '2fLgA3gGDfiFqXVTDD',
#    'url': 'https://giphy.com/gifs/spicegirls-reaction-mood-spice-girls-2fLgA3gGDfiFqXVTDD',
#    'slug': 'spicegirls-reaction-mood-spice-girls-2fLgA3gGDfiFqXVTDD',
#    'bitly_gif_url': 'https://gph.is/g/ZyNo5W4',
#    'bitly_url': 'https://gph.is/g/ZyNo5W4',
#    'embed_url': 'https://giphy.com/embed/2fLgA3gGDfiFqXVTDD',
#    'username': 'spicegirls',
#    'source': '',
#    'title': 'Galentines Day Friends GIF by Spice Girls',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2019-03-12 15:15:39',
#    'trending_datetime': '2026-02-20 16:30:03',
#    'images': {'original': {'height': '288',
#      'width': '480',
#      'size': '6957610',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy.gif',
#      'mp4_size': '984778',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy.mp4',
#      'webp_size': '3018512',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy.webp',
#      'frames': '119',
#      'hash': 'e904eea128450ca7dff596ba5994295a'},
#     'downsized': {'height': '184',
#      'width': '308',
#      'size': '1792305',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-downsized.gif'},
#     'downsized_large': {'height': '288',
#      'width': '480',
#      'size': '6957610',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy.gif'},
#     'downsized_medium': {'height': '230',
#      'width': '384',
#      'size': '3807054',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-downsized-medium.gif'},
#     'downsized_small': {'height': '192',
#      'width': '320',
#      'mp4_size': '197517',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '184',
#      'width': '308',
#      'size': '25543',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-downsized_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '334',
#      'size': '3156222',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200.gif',
#      'mp4_size': '705676',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200.mp4',
#      'webp_size': '1813750',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '334',
#      'size': '152960',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200_d.gif',
#      'webp_size': '116074',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '164',
#      'size': '1061000',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100.gif',
#      'mp4_size': '232106',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100.mp4',
#      'webp_size': '518876',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '164',
#      'size': '9000',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '334',
#      'size': '24713',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200_s.gif'},
#     'fixed_width': {'height': '120',
#      'width': '200',
#      'size': '1468455',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w.gif',
#      'mp4_size': '326440',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w.mp4',
#      'webp_size': '699534',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w.webp'},
#     'fixed_width_downsampled': {'height': '120',
#      'width': '200',
#      'size': '79342',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w_d.gif',
#      'webp_size': '49952',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w_d.webp'},
#     'fixed_width_small': {'height': '60',
#      'width': '100',
#      'size': '409192',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100w.gif',
#      'mp4_size': '96225',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100w.mp4',
#      'webp_size': '239636',
#      'webp': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100w.webp'},
#     'fixed_width_small_still': {'height': '60',
#      'width': '100',
#      'size': '4286',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/100w_s.gif'},
#     'fixed_width_still': {'height': '120',
#      'width': '200',
#      'size': '13930',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/200w_s.gif'},
#     'looping': {'height': '288',
#      'width': '480',
#      'mp4_size': '4703458',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-loop.mp4'},
#     'original_still': {'height': '288',
#      'width': '480',
#      'size': '44418',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy_s.gif'},
#     'original_mp4': {'height': '288',
#      'width': '480',
#      'mp4_size': '984778',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy.mp4'},
#     'preview': {'height': '72',
#      'width': '120',
#      'mp4_size': '46287',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-preview.mp4'},
#     'preview_gif': {'height': '60',
#      'width': '100',
#      'size': '35103',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-preview.gif'},
#     'preview_webp': {'height': '60',
#      'width': '100',
#      'size': '31100',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-preview.webp'},
#     'hd': {'height': '494',
#      'width': '824',
#      'mp4_size': '3540503',
#      'mp4': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/giphy-hd.mp4'},
#     '480w_still': {'height': '288',
#      'width': '480',
#      'size': '6957610',
#      'url': 'https://media3.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2fLgA3gGDfiFqXVTDD/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/spicegirls/67af7krsqCMo.png',
#     'banner_image': 'https://media3.giphy.com/headers/spicegirls/avFOfIEK8MzN.jpg',
#     'banner_url': 'https://media3.giphy.com/headers/spicegirls/avFOfIEK8MzN.jpg',
#     'profile_url': 'https://giphy.com/spicegirls/',
#     'username': 'spicegirls',
#     'display_name': 'Spice Girls',
#     'description': 'Official Spice Girls GIPHY',
#     'instagram_url': 'https://instagram.com/spicegirls',
#     'website_url': 'http://thespicegirls.com',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9MmZMZ0EzZ0dEZmlGcVhWVEREJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9MmZMZ0EzZ0dEZmlGcVhWVEREJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9MmZMZ0EzZ0dEZmlGcVhWVEREJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9MmZMZ0EzZ0dEZmlGcVhWVEREJmN0PWc&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': '3ohzdIk6GgMh1T6ldC',
#    'url': 'https://giphy.com/gifs/prepareforwinter-game-of-thrones-snow-3ohzdIk6GgMh1T6ldC',
#    'slug': 'prepareforwinter-game-of-thrones-snow-3ohzdIk6GgMh1T6ldC',
#    'bitly_gif_url': 'http://gph.is/2qhJQmP',
#    'bitly_url': 'http://gph.is/2qhJQmP',
#    'embed_url': 'https://giphy.com/embed/3ohzdIk6GgMh1T6ldC',
#    'username': 'gameofthrones',
#    'source': '',
#    'title': 'Prepare Season 7 GIF by Game of Thrones',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2017-05-23 20:21:08',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '225',
#      'width': '400',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.gif',
#      'mp4_size': '369108',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.mp4',
#      'webp_size': '549104',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.webp',
#      'frames': '89',
#      'hash': '7d59540c0034b96c8b69cd0cc0715ec2'},
#     'downsized': {'height': '225',
#      'width': '400',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.gif'},
#     'downsized_large': {'height': '225',
#      'width': '400',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.gif'},
#     'downsized_medium': {'height': '225',
#      'width': '400',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.gif'},
#     'downsized_small': {'height': '224',
#      'width': '400',
#      'mp4_size': '197742',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '225',
#      'width': '400',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '358',
#      'size': '1337939',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200.gif',
#      'mp4_size': '319339',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200.mp4',
#      'webp_size': '443714',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '358',
#      'size': '84401',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200_d.gif',
#      'webp_size': '54272',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '176',
#      'size': '437733',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100.gif',
#      'mp4_size': '93765',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100.mp4',
#      'webp_size': '116670',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '176',
#      'size': '4967',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '358',
#      'size': '13876',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200_s.gif'},
#     'fixed_width': {'height': '112',
#      'width': '200',
#      'size': '500602',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w.gif',
#      'mp4_size': '110234',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w.mp4',
#      'webp_size': '140948',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w.webp'},
#     'fixed_width_downsampled': {'height': '112',
#      'width': '200',
#      'size': '32269',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w_d.gif',
#      'webp_size': '19110',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w_d.webp'},
#     'fixed_width_small': {'height': '56',
#      'width': '100',
#      'size': '188597',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100w.gif',
#      'mp4_size': '38102',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100w.mp4',
#      'webp_size': '55042',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100w.webp'},
#     'fixed_width_small_still': {'height': '56',
#      'width': '100',
#      'size': '2608',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/100w_s.gif'},
#     'fixed_width_still': {'height': '112',
#      'width': '200',
#      'size': '5724',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/200w_s.gif'},
#     'looping': {'height': '268',
#      'width': '478',
#      'mp4_size': '1976430',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy-loop.mp4'},
#     'original_still': {'height': '225',
#      'width': '400',
#      'size': '13881',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy_s.gif'},
#     'original_mp4': {'height': '224',
#      'width': '400',
#      'mp4_size': '369108',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy.mp4'},
#     'preview': {'height': '84',
#      'width': '150',
#      'mp4_size': '32027',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy-preview.mp4'},
#     'preview_gif': {'height': '56',
#      'width': '100',
#      'size': '19005',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy-preview.gif'},
#     'preview_webp': {'height': '56',
#      'width': '100',
#      'size': '40258',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/giphy-preview.webp'},
#     '480w_still': {'height': '270',
#      'width': '480',
#      'size': '1650832',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/3ohzdIk6GgMh1T6ldC/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/gameofthrones/tIs2vVQvTLYF.jpg',
#     'banner_image': 'https://media3.giphy.com/channel_assets/gameofthrones/Yun4s3o9J7l1.jpg',
#     'banner_url': 'https://media3.giphy.com/channel_assets/gameofthrones/Yun4s3o9J7l1.jpg',
#     'profile_url': 'https://giphy.com/gameofthrones/',
#     'username': 'gameofthrones',
#     'display_name': 'Game of Thrones',
#     'description': 'This Winter, Spring is Coming. Meet Dunk and Egg in #AKnightoftheSevenKingdoms, the new #GOT series, premieres January on @HBOMax.',
#     'instagram_url': '',
#     'website_url': 'https://www.hbomax.com/got',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9M29oemRJazZHZ01oMVQ2bGRDJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9M29oemRJazZHZ01oMVQ2bGRDJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9M29oemRJazZHZ01oMVQ2bGRDJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9M29oemRJazZHZ01oMVQ2bGRDJmN0PWc&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': 'JDR34LsvbuQ23zpzyQ',
#    'url': 'https://giphy.com/gifs/firstwefeast-chicken-wings-madison-beer-hot-JDR34LsvbuQ23zpzyQ',
#    'slug': 'firstwefeast-chicken-wings-madison-beer-hot-JDR34LsvbuQ23zpzyQ',
#    'bitly_gif_url': 'https://gph.is/g/E0My9BX',
#    'bitly_url': 'https://gph.is/g/E0My9BX',
#    'embed_url': 'https://giphy.com/embed/JDR34LsvbuQ23zpzyQ',
#    'username': 'firstwefeast',
#    'source': '',
#    'title': 'Chicken Wings Hot Ones GIF by First We Feast',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2026-02-19 21:33:50',
#    'trending_datetime': '2026-02-20 16:15:03',
#    'images': {'original': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.gif',
#      'mp4_size': '259274',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.mp4',
#      'webp_size': '373284',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.webp',
#      'frames': '19',
#      'hash': 'f849ef09705b288f115a3b843513a28a'},
#     'downsized': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.gif'},
#     'downsized_large': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.gif'},
#     'downsized_medium': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.gif'},
#     'downsized_small': {'height': '340',
#      'width': '340',
#      'mp4_size': '193506',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '200',
#      'size': '252452',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200.gif',
#      'mp4_size': '64661',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200.mp4',
#      'webp_size': '118834',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '200',
#      'size': '83555',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200_d.gif',
#      'webp_size': '49312',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '100',
#      'size': '84526',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100.gif',
#      'mp4_size': '23488',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100.mp4',
#      'webp_size': '40234',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '100',
#      'size': '5747',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '200',
#      'size': '21438',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200_s.gif'},
#     'fixed_width': {'height': '200',
#      'width': '200',
#      'size': '252452',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w.gif',
#      'mp4_size': '64661',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w.mp4',
#      'webp_size': '100122',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w.webp'},
#     'fixed_width_downsampled': {'height': '200',
#      'width': '200',
#      'size': '83555',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w_d.gif',
#      'webp_size': '49312',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w_d.webp'},
#     'fixed_width_small': {'height': '100',
#      'width': '100',
#      'size': '84526',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100w.gif',
#      'mp4_size': '23488',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100w.mp4',
#      'webp_size': '40234',
#      'webp': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100w.webp'},
#     'fixed_width_small_still': {'height': '100',
#      'width': '100',
#      'size': '5747',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100w_s.gif'},
#     'fixed_width_still': {'height': '200',
#      'width': '200',
#      'size': '21438',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/200w_s.gif'},
#     'looping': {},
#     'original_still': {'height': '480',
#      'width': '480',
#      'size': '107191',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy_s.gif'},
#     'original_mp4': {'height': '480',
#      'width': '480',
#      'mp4_size': '259274',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy.mp4'},
#     'preview': {'height': '150',
#      'width': '150',
#      'mp4_size': '40943',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy-preview.mp4'},
#     'preview_gif': {'height': '100',
#      'width': '100',
#      'size': '42087',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy-preview.gif'},
#     'preview_webp': {'height': '100',
#      'width': '100',
#      'size': '40234',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/100.webp'},
#     'hd': {'height': '1080',
#      'width': '1080',
#      'mp4_size': '1031505',
#      'mp4': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/giphy-hd.mp4'},
#     '480w_still': {'height': '480',
#      'width': '480',
#      'size': '1328994',
#      'url': 'https://media1.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/JDR34LsvbuQ23zpzyQ/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/firstwefeast/Yj2N2LYLYAtE.png',
#     'banner_image': 'https://media3.giphy.com/channel_assets/firstwefeast/eC0fWWWfWQVd.jpg',
#     'banner_url': 'https://media3.giphy.com/channel_assets/firstwefeast/eC0fWWWfWQVd.jpg',
#     'profile_url': 'https://giphy.com/firstwefeast/',
#     'username': 'firstwefeast',
#     'display_name': 'First We Feast',
#     'description': 'Bridging the gap between food, drinks, & pop culture.',
#     'instagram_url': 'https://instagram.com/firstwefeast',
#     'website_url': 'https://firstwefeast.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9SkRSMzRMc3ZidVEyM3pwenlRJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9SkRSMzRMc3ZidVEyM3pwenlRJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9SkRSMzRMc3ZidVEyM3pwenlRJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9SkRSMzRMc3ZidVEyM3pwenlRJmN0PWc&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': '2nv2kB8m8RlkM2r0HW',
#    'url': 'https://giphy.com/gifs/pudgypenguins-good-morning-gm-2nv2kB8m8RlkM2r0HW',
#    'slug': 'pudgypenguins-good-morning-gm-2nv2kB8m8RlkM2r0HW',
#    'bitly_gif_url': 'https://gph.is/g/4VwBJrO',
#    'bitly_url': 'https://gph.is/g/4VwBJrO',
#    'embed_url': 'https://giphy.com/embed/2nv2kB8m8RlkM2r0HW',
#    'username': 'pudgypenguins',
#    'source': '',
#    'title': 'Good Morning Hello GIF by Pudgy Penguins',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2026-01-27 22:02:28',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.gif',
#      'mp4_size': '65820',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.mp4',
#      'webp_size': '122032',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.webp',
#      'frames': '9',
#      'hash': '53c1fa46e5a6f639f9f876abff299805'},
#     'downsized': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.gif'},
#     'downsized_large': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.gif'},
#     'downsized_medium': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.gif'},
#     'downsized_small': {'height': '480',
#      'width': '480',
#      'mp4_size': '65820',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '200',
#      'size': '41141',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200.gif',
#      'mp4_size': '25018',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200.mp4',
#      'webp_size': '40212',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '200',
#      'size': '30954',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200_d.gif',
#      'webp_size': '31880',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '100',
#      'size': '18128',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100.gif',
#      'mp4_size': '10493',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100.mp4',
#      'webp_size': '13654',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '100',
#      'size': '3852',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '200',
#      'size': '9276',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200_s.gif'},
#     'fixed_width': {'height': '200',
#      'width': '200',
#      'size': '41141',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w.gif',
#      'mp4_size': '25018',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w.mp4',
#      'webp_size': '34872',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w.webp'},
#     'fixed_width_downsampled': {'height': '200',
#      'width': '200',
#      'size': '30954',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w_d.gif',
#      'webp_size': '31880',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w_d.webp'},
#     'fixed_width_small': {'height': '100',
#      'width': '100',
#      'size': '18128',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100w.gif',
#      'mp4_size': '10493',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100w.mp4',
#      'webp_size': '13654',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100w.webp'},
#     'fixed_width_small_still': {'height': '100',
#      'width': '100',
#      'size': '3852',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100w_s.gif'},
#     'fixed_width_still': {'height': '200',
#      'width': '200',
#      'size': '9276',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/200w_s.gif'},
#     'looping': {},
#     'original_still': {'height': '480',
#      'width': '480',
#      'size': '29963',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy_s.gif'},
#     'original_mp4': {'height': '480',
#      'width': '480',
#      'mp4_size': '65820',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy.mp4'},
#     'preview': {'height': '200',
#      'width': '200',
#      'mp4_size': '25018',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/giphy-preview.mp4'},
#     'preview_gif': {'height': '100',
#      'width': '100',
#      'size': '18128',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100.gif'},
#     'preview_webp': {'height': '100',
#      'width': '100',
#      'size': '13654',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/100.webp'},
#     '480w_still': {'height': '480',
#      'width': '480',
#      'size': '141588',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2nv2kB8m8RlkM2r0HW/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/pudgypenguins/wGSQYg1jocYv.jpg',
#     'banner_image': 'https://media3.giphy.com/channel_assets/pudgypenguins/XRQOFIzKAxsw.png',
#     'banner_url': 'https://media3.giphy.com/channel_assets/pudgypenguins/XRQOFIzKAxsw.png',
#     'profile_url': 'https://giphy.com/pudgypenguins/',
#     'username': 'pudgypenguins',
#     'display_name': 'Pudgy Penguins',
#     'description': 'The Pudgy Penguins waddle through the internet to supply unlimited memes & good vibes.',
#     'instagram_url': 'https://instagram.com/pudgypenguins',
#     'website_url': 'http://pudgypenguins.com/',
#     'is_verified': True},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9Mm52MmtCOG04UmxrTTJyMEhXJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9Mm52MmtCOG04UmxrTTJyMEhXJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9Mm52MmtCOG04UmxrTTJyMEhXJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9Mm52MmtCOG04UmxrTTJyMEhXJmN0PWc&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': '9jvjuSSkMOYTyQfJji',
#    'url': 'https://giphy.com/gifs/outsidetv-9jvjuSSkMOYTyQfJji',
#    'slug': 'outsidetv-9jvjuSSkMOYTyQfJji',
#    'bitly_gif_url': 'https://gph.is/g/ZWb9M6X',
#    'bitly_url': 'https://gph.is/g/ZWb9M6X',
#    'embed_url': 'https://giphy.com/embed/9jvjuSSkMOYTyQfJji',
#    'username': 'outsidetv',
#    'source': '',
#    'title': 'Winter Storm Snow GIF by Outside Watch',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2021-10-18 20:33:12',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '270',
#      'width': '480',
#      'size': '520748',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.gif',
#      'mp4_size': '140579',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.mp4',
#      'webp_size': '101122',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.webp',
#      'frames': '51',
#      'hash': '9ba52814396f27bf1230b617abae504e'},
#     'downsized': {'height': '270',
#      'width': '480',
#      'size': '520748',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.gif'},
#     'downsized_large': {'height': '270',
#      'width': '480',
#      'size': '520748',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.gif'},
#     'downsized_medium': {'height': '270',
#      'width': '480',
#      'size': '520748',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy.gif'},
#     'downsized_small': {'height': '270',
#      'width': '480',
#      'mp4_size': '140579',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '270',
#      'width': '480',
#      'size': '520748',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/giphy_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '356',
#      'size': '396638',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/200.gif',
#      'mp4_size': '86858',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/9jvjuSSkMOYTyQfJji/200.mp4',
#      'webp_size': '68540',
# ...
#      'webp_size': '147518',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/200w.webp'},
#     'fixed_width_downsampled': {'height': '120',
#      'width': '200',
#      'size': '56180',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/200w_d.gif',
#      'webp_size': '31662',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/200w_d.webp'},
#     'fixed_width_small': {'height': '60',
#      'width': '100',
#      'size': '120691',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/100w.gif',
#      'mp4_size': '28457',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/100w.mp4',
#      'webp_size': '54698',
#      'webp': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/100w.webp'},
#     'fixed_width_small_still': {'height': '60',
#      'width': '100',
#      'size': '6176',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/100w_s.gif'},
#     'fixed_width_still': {'height': '120',
#      'width': '200',
#      'size': '17326',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/200w_s.gif'},
#     'looping': {'height': '288',
#      'width': '480',
#      'mp4_size': '1515881',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy-loop.mp4'},
#     'original_still': {'height': '288',
#      'width': '480',
#      'size': '80085',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy_s.gif'},
#     'original_mp4': {'height': '288',
#      'width': '481',
#      'mp4_size': '332534',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy.mp4'},
#     'preview': {'height': '90',
#      'width': '150',
#      'mp4_size': '44056',
#      'mp4': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy-preview.mp4'},
#     'preview_gif': {'height': '60',
#      'width': '100',
#      'size': '24009',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy-preview.gif'},
#     'preview_webp': {'height': '60',
#      'width': '100',
#      'size': '42760',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/giphy-preview.webp'},
#     '480w_still': {'height': '288',
#      'width': '480',
#      'size': '1866835',
#      'url': 'https://media0.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/QBd2kLB5qDmysEXre9/480w_s.jpg'}},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9UUJkMmtMQjVxRG15c0VYcmU5JmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9UUJkMmtMQjVxRG15c0VYcmU5JmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9UUJkMmtMQjVxRG15c0VYcmU5JmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9UUJkMmtMQjVxRG15c0VYcmU5JmN0PWc&action_type=SENT'}},
#    'alt_text': "Movie gif. Rowan Atkinson as Mr. Bean in Mr. Bean's Holiday, stands in a field of yellow flowers on a windy day. He looks off into the distance and then at his watch, before scratching his head. ",
#    'is_low_contrast': False},
#   {'type': 'gif',
#    'id': 'fa1AV8UvZvfBFOIt7F',
#    'url': 'https://giphy.com/gifs/meme-relatable-cramel-fa1AV8UvZvfBFOIt7F',
#    'slug': 'meme-relatable-cramel-fa1AV8UvZvfBFOIt7F',
#    'bitly_gif_url': 'https://gph.is/g/4DrN5Av',
#    'bitly_url': 'https://gph.is/g/4DrN5Av',
#    'embed_url': 'https://giphy.com/embed/fa1AV8UvZvfBFOIt7F',
#    'username': 'stellamakesgifs',
#    'source': '',
#    'title': 'Thinking What GIF',
#    'rating': 'g',
#    'content_url': '',
#    'source_tld': '',
#    'source_post_url': '',
#    'is_sticker': 0,
#    'import_datetime': '2025-12-26 13:00:22',
#    'trending_datetime': '0000-00-00 00:00:00',
#    'images': {'original': {'height': '480',
#      'width': '480',
#      'size': '2200494',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.gif',
#      'mp4_size': '471941',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.mp4',
#      'webp_size': '669288',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.webp',
#      'frames': '25',
#      'hash': 'bb2fc3d9d88e07d7a8248d23c476ecf2'},
#     'downsized': {'height': '480',
#      'width': '480',
#      'size': '1726011',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-downsized.gif'},
#     'downsized_large': {'height': '480',
#      'width': '480',
#      'size': '2200494',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.gif'},
#     'downsized_medium': {'height': '480',
#      'width': '480',
#      'size': '2200494',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.gif'},
#     'downsized_small': {'height': '400',
#      'width': '400',
#      'mp4_size': '191539',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-downsized-small.mp4'},
#     'downsized_still': {'height': '480',
#      'width': '480',
#      'size': '123061',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-downsized_s.gif'},
#     'fixed_height': {'height': '200',
#      'width': '200',
#      'size': '407901',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200.gif',
#      'mp4_size': '100131',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200.mp4',
#      'webp_size': '186794',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200.webp'},
#     'fixed_height_downsampled': {'height': '200',
#      'width': '200',
#      'size': '94566',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200_d.gif',
#      'webp_size': '59654',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200_d.webp'},
#     'fixed_height_small': {'height': '100',
#      'width': '100',
#      'size': '132283',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100.gif',
#      'mp4_size': '36191',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100.mp4',
#      'webp_size': '57340',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100.webp'},
#     'fixed_height_small_still': {'height': '100',
#      'width': '100',
#      'size': '9843',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100_s.gif'},
#     'fixed_height_still': {'height': '200',
#      'width': '200',
#      'size': '30020',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200_s.gif'},
#     'fixed_width': {'height': '200',
#      'width': '200',
#      'size': '407901',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w.gif',
#      'mp4_size': '100131',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w.mp4',
#      'webp_size': '151998',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w.webp'},
#     'fixed_width_downsampled': {'height': '200',
#      'width': '200',
#      'size': '94566',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w_d.gif',
#      'webp_size': '59654',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w_d.webp'},
#     'fixed_width_small': {'height': '100',
#      'width': '100',
#      'size': '132283',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100w.gif',
#      'mp4_size': '36191',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100w.mp4',
#      'webp_size': '57340',
#      'webp': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100w.webp'},
#     'fixed_width_small_still': {'height': '100',
#      'width': '100',
#      'size': '9843',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/100w_s.gif'},
#     'fixed_width_still': {'height': '200',
#      'width': '200',
#      'size': '30020',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/200w_s.gif'},
#     'looping': {},
#     'original_still': {'height': '480',
#      'width': '480',
#      'size': '140133',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy_s.gif'},
#     'original_mp4': {'height': '480',
#      'width': '480',
#      'mp4_size': '471941',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy.mp4'},
#     'preview': {'height': '150',
#      'width': '150',
#      'mp4_size': '39592',
#      'mp4': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-preview.mp4'},
#     'preview_gif': {'height': '100',
#      'width': '100',
#      'size': '48508',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-preview.gif'},
#     'preview_webp': {'height': '100',
#      'width': '100',
#      'size': '42212',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/giphy-preview.webp'},
#     '480w_still': {'height': '480',
#      'width': '480',
#      'size': '2200494',
#      'url': 'https://media4.giphy.com/media/v1.Y2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/fa1AV8UvZvfBFOIt7F/480w_s.jpg'}},
#    'user': {'avatar_url': 'https://media3.giphy.com/avatars/stellamakesgifs/uVmuiQs57pct.gif',
#     'banner_image': '',
#     'banner_url': '',
#     'profile_url': 'https://giphy.com/channel/stellamakesgifs/',
#     'username': 'stellamakesgifs',
#     'display_name': 'stella',
#     'description': "uhm i like making funny meme gifs that's trending (:",
#     'instagram_url': 'https://instagram.com/stellapmo',
#     'website_url': 'http://carrd.co/dashboard/7244167789895536/build',
#     'is_verified': False},
#    'analytics_response_payload': 'e=ZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9ZmExQVY4VXZadmZCRk9JdDdGJmN0PWc',
#    'analytics': {'onload': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9ZmExQVY4VXZadmZCRk9JdDdGJmN0PWc&action_type=SEEN'},
#     'onclick': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9ZmExQVY4VXZadmZCRk9JdDdGJmN0PWc&action_type=CLICK'},
#     'onsent': {'url': 'https://giphy-analytics.giphy.com/v2/pingback_simple?analytics_response_payload=e%3DZXZlbnRfdHlwZT1HSUZfVFJFTkRJTkcmY2lkPWY3ZjFjMmU4Z3huMTlyeGJld2VpdDYyeWw3dTloMWhzZm1wdmd6ajNhbzM2amZrdCZnaWZfaWQ9ZmExQVY4VXZadmZCRk9JdDdGJmN0PWc&action_type=SENT'}},
#    'alt_text': '',
#    'is_low_contrast': False}],
#  'meta': {'status': 200,
#   'msg': 'OK',
#   'response_id': 'gxn19rxbeweit62yl7u9h1hsfmpvgzj3ao36jfkt'},
#  'pagination': {'total_count': 500, 'count': 50, 'offset': 0}}

# %%
for gif in response.json()['data']:
    print(gif['url'])
# Out:
# https://giphy.com/gifs/spicegirls-reaction-mood-spice-girls-2fLgA3gGDfiFqXVTDD
# https://giphy.com/gifs/prepareforwinter-game-of-thrones-snow-3ohzdIk6GgMh1T6ldC
# https://giphy.com/gifs/firstwefeast-chicken-wings-madison-beer-hot-JDR34LsvbuQ23zpzyQ
# https://giphy.com/gifs/pudgypenguins-good-morning-gm-2nv2kB8m8RlkM2r0HW
# https://giphy.com/gifs/outsidetv-9jvjuSSkMOYTyQfJji
# https://giphy.com/gifs/GrindCoin-67-6-7-six-seven-YaP3iYxN3T8nIEN5rD
# https://giphy.com/gifs/sad-cry-sadness-H6cmWzp6LGFvqjidB7
# https://giphy.com/gifs/oceanx-help-halp-so-confused-7SIdExk63rTPXhbbbt
# https://giphy.com/gifs/hi-door-elmo-6EDGSznQA5kVCa0DfD
# https://giphy.com/gifs/dtGIRL0FDp6nnOPGb5
# https://giphy.com/gifs/p4msJgypWkSfb3NERl
# https://giphy.com/gifs/pudgypenguins-gm-coffee-time-oclock-6Vv2LZkO0PxT7DjSZN
# https://giphy.com/gifs/washington-denzel-training-day-IorAqDrjKiDcc3QdN3
# https://giphy.com/gifs/onegreatforce-lets-go-goo-goooo-BBBx74mQ4a5sQoZydk
# https://giphy.com/gifs/outsidetv-outside-under-an-arctic-sky-023GUNo0864Vzgu4n6
# https://giphy.com/gifs/human-helloo-1fMjj5j2Z7chq
# https://giphy.com/gifs/magicedenofficial-snow-snowing-storm-tslXHimHDcHcLx4lnt
# https://giphy.com/gifs/67-six-seven-john-chungus-08uBcURaMq6vA93TGc
# https://giphy.com/gifs/bombaysoftwares-waiting-mr-bean-still-um2kBnfo55iW4ZH1Fa
# https://giphy.com/gifs/no-ji6zzUZwNIuLS
# https://giphy.com/gifs/soultrain-soul-train-comedian-l4EpaYohEXOTFCm0E
# https://giphy.com/gifs/dog-poodle-pearls-WK7omsLop0431tZjXb
# https://giphy.com/gifs/lol-laugh-laughing-gj0QdZ9FgqGhOBNlFS
# https://giphy.com/gifs/IZEAofficial-coffee-time-izea-AZQGMIiEK8yDfGEn55
# https://giphy.com/gifs/nhl-sports-hockey-fan-t3sZxY5zS5B0z5zMIz
# https://giphy.com/gifs/curious-bully-amstaff-pl8L3FwRCX5L2akQj8
# https://giphy.com/gifs/foxhomeent-fox-snow-3ohzdUy4XV6veSrxZK
# https://giphy.com/gifs/goofball-6767-676767-XMMUWcz4XtDTNgZj22
# https://giphy.com/gifs/kim-novak-tXL4FHPSnVJ0A
# https://giphy.com/gifs/what-the-fuck-wtf-ukGm72ZLZvYfS
# https://giphy.com/gifs/foxhomeent-hello-friday-mrs-doubtfire-28GHfhGFWpFgsQB4wR
# https://giphy.com/gifs/lol-laughing-hehe-Tq2tPTrQANKfK
# https://giphy.com/gifs/coffee-barista-latteart-8cN6wDcWdzEGBsIRya
# https://giphy.com/gifs/excited-yes-nicolas-cage-RrVzUOXldFe8M
# https://giphy.com/gifs/PandaPals--bm-basenetwork-basedmorning-QUPRW8DWGdeqUbYlao
# https://giphy.com/gifs/looneytunes-looney-tunes-sylvester-elmer-fudd-igI6MV8C7Ld4OWFesG
# https://giphy.com/gifs/lifetimetv-lifetime-its-a-wonderful-the-road-home-for-christmas-l0jepPckjfLJ6D8PDQ
# https://giphy.com/gifs/RespectiveCollective-bills-mafia-mike-miglioranzi-buffalo-67-jvtsd83r7wVm90y1PO
# https://giphy.com/gifs/waiting-hd-well-were-9SIXFu7bIUYHhFc19G
# https://giphy.com/gifs/robert-downey-jr-sigh-confused-116a8zosxwA0SI
# https://giphy.com/gifs/minions-despicableme-despicableme4-despicablememovie-S2IfEQqgWc0AH4r6Al
# https://giphy.com/gifs/Goosify-funny-laughing-haha-vbqr9NgKRuKq7meXsi
# https://giphy.com/gifs/baby-yoda-mandalorian-grogu-4k4pxbTamKLLxE3HXT
# https://giphy.com/gifs/1huddleplay-lets-go-gametime-1huddle-5UAofAl6g5t1GL5nO8
# https://giphy.com/gifs/GrindCoin-snow-snowing-blizzard-kJnOdMFzOGKUPt3rFb
# https://giphy.com/gifs/morning-person-perfect-loops-9s8Jq3Sc1ZnZS
# https://giphy.com/gifs/jerseydemic-26xBwFcBGPLNfGbkY
# https://giphy.com/gifs/brainrot-67-spongeball-g2mQaLCGAm3k7OpIN9
# https://giphy.com/gifs/time-mr-bean-look-at-the-QBd2kLB5qDmysEXre9
# https://giphy.com/gifs/meme-relatable-cramel-fa1AV8UvZvfBFOIt7F

# %%
import requests


def get_exchange_rate(base_currency, target_currency):
    url = f"https://api.exchangerate-api.com/v4/latest/{base_currency}"
    response = requests.get(url)
    return response.json()['rates'][target_currency]

# %%
base = "USD"
target = "IRR"
base_currency_amount = 100
exchange_rate = get_exchange_rate(base, target)

exchange_rate
# Out:
# 1284718.39

# %%
def conventor_currency(base_currency_amount, exchange_rate):
    return base_currency_amount * exchange_rate

conventor_currency(100, exchange_rate)
# Out:
# 128471838.99999999

# %%
import requests
url = f"https://api.exchangerate-api.com/v4/latest/{base}"
response = requests.get(url)
response.json()['rates'][target]
# Out:
# 1284718.39

# %%
response
# Out:
# <Response [200]>

# %%
CAD_amount = 100
USD_amount = CAD_amount * exchange_rate

# %%
url = f"https://api.exchangerate-api.com/v4/latest/USD"
response = requests.get(url)

# %%
list(response.json()['rates'].keys())
# Out:
# ['USD',
#  'AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLF',
#  'CLP',
#  'CNH',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'FOK',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KID',
#  'KMF',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRU',
#  'MUR',
#  'MVR',
#  'MWK',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PAB',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SBD',
#  'SCR',
#  'SDG',
#  'SEK',
#  'SGD',
#  'SHP',
#  'SLE',
#  'SLL',
#  'SOS',
#  'SRD',
#  'SSP',
#  'STN',
#  'SYP',
#  'SZL',
#  'THB',
#  'TJS',
#  'TMT',
#  'TND',
#  'TOP',
#  'TRY',
#  'TTD',
#  'TVD',
#  'TWD',
#  'TZS',
#  'UAH',
#  'UGX',
#  'UYU',
#  'UZS',
#  'VES',
#  'VND',
#  'VUV',
#  'WST',
#  'XAF',
#  'XCD',
#  'XCG',
#  'XDR',
#  'XOF',
#  'XPF',
#  'YER',
#  'ZAR',
#  'ZMW',
#  'ZWG',
#  'ZWL']
